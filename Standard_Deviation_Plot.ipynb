# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2024-09-12 15:22:25.397663: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2.4.1

# %%
confusion_matrix = tf.keras.metrics.ConfusionMatrix(num_classes=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 confusion_matrix = tf.keras.metrics.ConfusionMatrix(num_classes=2)
#
# AttributeError: module 'tensorflow.keras.metrics' has no attribute 'ConfusionMatrix'
