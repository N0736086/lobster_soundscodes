# %%
import os
import librosa
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.decomposition import PCA
import time
import pandas as pd

# Function to extract MFCCs from audio files
def extract_mfccs(file_path):
    try:
        y, sr = librosa.load(file_path, duration=1)  # Load 1-second audio
        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
        return np.mean(mfccs.T, axis=0)  # Average MFCCs over time
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None

# Data Loading and Feature Extraction
male_folder = "/home/feliciano/adult_lobsters"  # Replace with your actual male folder name if different
female_folder = "/home/feliciano/juvenile_lobsters" # Replace with your actual female folder name if different

data = []
labels = []

for filename in os.listdir(male_folder):
    file_path = os.path.join(male_folder, filename)
    if os.path.isfile(file_path) and filename.endswith(('.wav', '.mp3', '.ogg', '.flac')):
        mfccs = extract_mfccs(file_path)
        if mfccs is not None:
            data.append(mfccs)
            labels.append("adult")

for filename in os.listdir(female_folder):
    file_path = os.path.join(female_folder, filename)
    if os.path.isfile(file_path) and filename.endswith(('.wav', '.mp3', '.ogg', '.flac')):
        mfccs = extract_mfccs(file_path)
        if mfccs is not None:
            data.append(mfccs)
            labels.append("juvenile")

if not data:
    print("No audio files found in the specified folders.")
    exit()

X = np.array(data)
y = np.array(labels)

# Label Encoding and Data Scaling
le = LabelEncoder()
y = le.fit_transform(y)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# PCA
n_components = min(X_train.shape[1], 30)  # You can adjust this
pca = PCA(n_components=n_components)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

print(f"Original feature shape: {X_train.shape}")
print(f"Shape after PCA: {X_train_pca.shape}")
print(f"Explained variance ratio of the first {n_components} components: {pca.explained_variance_ratio_}")
print(f"Total explained variance: {sum(pca.explained_variance_ratio_):.4f}")

# Logistic Regression Model with Grid Search
param_grid = {
    'C': [0.1, 1, 10],
    'penalty': ['l1', 'l2'],  # Add penalty for regularization
    'solver': ['liblinear', 'saga'], # Solvers compatible with l1 and l2
    'max_iter': [1000, 2000]
}

grid_search = GridSearchCV(LogisticRegression(random_state=42), 
                           param_grid, 
                           cv=5, 
                           scoring='accuracy', 
                           verbose=2, 
                           n_jobs=-1)

start_time_grid = time.time()
grid_search.fit(X_train_pca, y_train)
end_time_grid = time.time()
grid_search_time = (end_time_grid - start_time_grid)

best_lr_model = grid_search.best_estimator_

y_pred_grid = best_lr_model.predict(X_test_pca)
y_pred_proba_grid = best_lr_model.predict_proba(X_test_pca)[:, 1]

# Calculate Metrics with PCA and Grid Search
accuracy_grid = accuracy_score(y_test, y_pred_grid)
precision_grid = precision_score(y_test, y_pred_grid)
recall_grid = recall_score(y_test, y_pred_grid)
f1_grid = f1_score(y_test, y_pred_grid)
auc_roc_grid = roc_auc_score(y_test, y_pred_proba_grid)

# Print Cross-Validation Results
print("\nCross-Validation Results:")
cv_results_df = pd.DataFrame(grid_search.cv_results_)
print(cv_results_df[['param_C', 'param_penalty', 'param_solver', 'mean_test_score', 'std_test_score', 'rank_test_score']])

# Print Best Model Results
print("\nBest Logistic Regression Model Performance after PCA and Grid Search:")
print(f"  Best Parameters: {grid_search.best_params_}")
print(f"  Accuracy: {accuracy_grid:.4f}")
print(f"  Precision: {precision_grid:.4f}")
print(f"  Recall: {recall_grid:.4f}")
print(f"  F1-Score: {f1_grid:.4f}")
print(f"  AUC-ROC: {auc_roc_grid:.4f}")
print(f"  Grid Search Time (s): {grid_search_time:.4f}")
print("\nNote: MAP-50 is not directly applicable for binary classification.")
# Out:
# Original feature shape: (5845, 40)
# Shape after PCA: (5845, 30)
# Explained variance ratio of the first 30 components: [0.18577848 0.12527327 0.08688638 0.0722473  0.05522119 0.04886062
#  0.03948363 0.03766436 0.03256437 0.02581114 0.02512    0.02336168
#  0.02092689 0.02011618 0.01889228 0.01731724 0.01611799 0.01517948
#  0.01336655 0.01318099 0.01215435 0.01144456 0.00933867 0.00858793
#  0.0082527  0.00780815 0.00685459 0.00638463 0.00562027 0.00495171]
# Total explained variance: 0.9748
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
#
# Cross-Validation Results:
#    param_C param_penalty param_solver  mean_test_score  std_test_score  \
# 0      0.1            l1    liblinear         0.959624        0.003954
# 1      0.1            l1         saga         0.959453        0.004766
# 2      0.1            l2    liblinear         0.959453        0.006461
# 3      0.1            l2         saga         0.959966        0.006501
# 4      0.1            l1    liblinear         0.959624        0.003954
# 5      0.1            l1         saga         0.959453        0.004766
# 6      0.1            l2    liblinear         0.959453        0.006461
# 7      0.1            l2         saga         0.959966        0.006501
# 8        1            l1    liblinear         0.961163        0.006461
# 9        1            l1         saga         0.960992        0.006369
# 10       1            l2    liblinear         0.960479        0.006249
# 11       1            l2         saga         0.960479        0.006319
# 12       1            l1    liblinear         0.961163        0.006461
# 13       1            l1         saga         0.960992        0.006369
# 14       1            l2    liblinear         0.960479        0.006249
# 15       1            l2         saga         0.960479        0.006319
# 16      10            l1    liblinear         0.960821        0.006249
# 17      10            l1         saga         0.960821        0.006249
# 18      10            l2    liblinear         0.960992        0.006277
# 19      10            l2         saga         0.960650        0.006379
# 20      10            l1    liblinear         0.960821        0.006249
# 21      10            l1         saga         0.960821        0.006249
# 22      10            l2    liblinear         0.960992        0.006277
# 23      10            l2         saga         0.960650        0.006379
#
#     rank_test_score
# 0                19
# 1                21
# 2                21
# 3                17
# 4                19
# 5                21
# 6                21
# 7                17
# 8                 1
# 9                 3
# 10               13
# 11               13
# 12                1
# 13                3
# 14               13
# 15               13
# 16                7
# 17                7
# 18                3
# 19               11
# 20                7
# 21                7
# 22                3
# 23               11
#
# Best Logistic Regression Model Performance after PCA and Grid Search:
#   Best Parameters: {'C': 1, 'max_iter': 1000, 'penalty': 'l1', 'solver': 'liblinear'}
#   Accuracy: 0.9631
#   Precision: 0.9487
#   Recall: 0.9409
#   F1-Score: 0.9448
#   AUC-ROC: 0.9906
#   Grid Search Time (s): 0.8883
#
# Note: MAP-50 is not directly applicable for binary classification.
# [CV] END .C=0.1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.1s
# [CV] END ........C=1, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ........C=1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ..C=10, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=2000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .......C=10, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=2000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ..C=10, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ..C=10, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ........C=1, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END .C=0.1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .......C=10, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ........C=1, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ..C=10, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=1000, penalty=l1, solver=saga; total time=   0.3s
# [CV] END ......C=0.1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ..C=10, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ........C=1, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END .C=0.1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=1000, penalty=l2, solver=saga; total time=   0.3s
# [CV] END ......C=0.1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .......C=10, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ..C=10, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=1000, penalty=l1, solver=saga; total time=   0.3s
# [CV] END ........C=1, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END .C=0.1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .......C=10, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=2000, penalty=l1, solver=saga; total time=   0.3s
# [CV] END .......C=10, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .......C=10, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=1000, penalty=l1, solver=saga; total time=   0.3s
# [CV] END ..C=10, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.1s
# [CV] END ........C=1, max_iter=1000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ..C=10, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ..C=10, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.1s
# [CV] END ...C=1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .......C=10, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ........C=1, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ........C=1, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ..C=10, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ........C=1, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .......C=10, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END .C=0.1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=2000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ........C=1, max_iter=2000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ..C=10, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .......C=10, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ........C=1, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=2000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=2000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ........C=1, max_iter=2000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END .C=0.1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ..C=10, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=2000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ..C=10, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ..C=10, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.1s
# [CV] END ...C=1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END .......C=10, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=1000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ........C=1, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=2000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ..C=10, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=2000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=1000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ..C=10, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=2000, penalty=l1, solver=saga; total time=   0.3s
# [CV] END ......C=0.1, max_iter=1000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=1000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END ..C=10, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ........C=1, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .......C=10, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=1000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .......C=10, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .C=0.1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=1000, penalty=l2, solver=saga; total time=   0.3s
# [CV] END .......C=10, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .......C=10, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END ......C=0.1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END .......C=10, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ......C=0.1, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...C=1, max_iter=2000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=10, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .......C=10, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.1s
# [CV] END ......C=0.1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END ........C=1, max_iter=2000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=1000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=0.1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
# [CV] END .......C=10, max_iter=1000, penalty=l1, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=1000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END .C=0.1, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ......C=0.1, max_iter=2000, penalty=l1, solver=saga; total time=   0.1s
# [CV] END ...C=1, max_iter=2000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ........C=1, max_iter=2000, penalty=l1, solver=saga; total time=   0.3s
# [CV] END .......C=10, max_iter=2000, penalty=l2, solver=saga; total time=   0.2s
# [CV] END .......C=10, max_iter=2000, penalty=l2, solver=saga; total time=   0.1s
