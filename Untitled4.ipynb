# %%
import os
import librosa
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.decomposition import PCA
import time
import pandas as pd  # For better visualization of CV results

# Function to extract MFCCs from audio files
def extract_mfccs(file_path):
    try:
        y, sr = librosa.load(file_path, duration=1)  # Load 1-second audio
        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=60)
        return np.mean(mfccs.T, axis=0)  # Average MFCCs over time
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None

# Data Loading and Feature Extraction
male_folder = "/home/feliciano/adult_lobsters"  # Replace with your actual male folder name if different
female_folder = "/home/feliciano/juvenile_lobsters" # Replace with your actual female folder name if different

data = []
labels = []

for filename in os.listdir(male_folder):
    file_path = os.path.join(male_folder, filename)
    if os.path.isfile(file_path) and filename.endswith(('.wav', '.mp3', '.ogg', '.flac')):
        mfccs = extract_mfccs(file_path)
        if mfccs is not None:
            data.append(mfccs)
            labels.append("adult")

for filename in os.listdir(female_folder):
    file_path = os.path.join(female_folder, filename)
    if os.path.isfile(file_path) and filename.endswith(('.wav', '.mp3', '.ogg', '.flac')):
        mfccs = extract_mfccs(file_path)
        if mfccs is not None:
            data.append(mfccs)
            labels.append("juvenile")

if not data:
    print("No audio files found in the specified folders.")
    exit()

X = np.array(data)
y = np.array(labels)

# Label Encoding and Data Scaling
le = LabelEncoder()
y = le.fit_transform(y)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# PCA
n_components = min(X_train.shape[1], 30) # Example: Reduce to a maximum of 30 components
pca = PCA(n_components=n_components)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

print(f"Original feature shape: {X_train.shape}")
print(f"Shape after PCA: {X_train_pca.shape}")
print(f"Explained variance ratio of the first {n_components} components: {pca.explained_variance_ratio_}")
print(f"Total explained variance: {sum(pca.explained_variance_ratio_):.4f}")

# SVM Model with Grid Search
param_grid = {
    'C': [0.1, 1, 10],
    'gamma': ['scale', 'auto', 0.001, 0.01],
    'kernel': ['linear', 'rbf']
}

grid_search = GridSearchCV(SVC(random_state=42, probability=True), param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)

start_time_grid = time.time()
grid_search.fit(X_train_pca, y_train)
end_time_grid = time.time()
grid_search_time = (end_time_grid - start_time_grid) #seconds

best_svm_model = grid_search.best_estimator_

y_pred_grid = best_svm_model.predict(X_test_pca)
y_pred_proba_grid = best_svm_model.predict_proba(X_test_pca)[:, 1]

# Calculate Metrics with PCA and Grid Search
accuracy_grid = accuracy_score(y_test, y_pred_grid)
precision_grid = precision_score(y_test, y_pred_grid)
recall_grid = recall_score(y_test, y_pred_grid)
f1_grid = f1_score(y_test, y_pred_grid)
auc_roc_grid = roc_auc_score(y_test, y_pred_proba_grid)

# Print Cross-Validation Results
print("\nCross-Validation Results:")
cv_results_df = pd.DataFrame(grid_search.cv_results_)
print(cv_results_df[['param_C', 'param_gamma', 'param_kernel', 'mean_test_score', 'std_test_score', 'rank_test_score']])

# Print Best Model Results
print("\nBest SVM Model Performance after PCA and Grid Search:")
print(f"  Best Parameters: {grid_search.best_params_}")
print(f"  Accuracy: {accuracy_grid:.4f}")
print(f"  Precision: {precision_grid:.4f}")
print(f"  Recall: {recall_grid:.4f}")
print(f"  F1-Score: {f1_grid:.4f}")
print(f"  AUC-ROC: {auc_roc_grid:.4f}")
print(f"  Grid Search Time (s): {grid_search_time:.4f}")
print("\nNote: MAP-50 is not directly applicable for binary classification.")
# Out:
# Original feature shape: (5845, 60)
# Shape after PCA: (5845, 30)
# Explained variance ratio of the first 30 components: [0.19666806 0.10417441 0.08138054 0.05794716 0.05558513 0.04463555
#  0.03685721 0.03339989 0.02750698 0.02429195 0.02156268 0.01988871
#  0.01812807 0.01659646 0.01491984 0.01438731 0.01328333 0.01289565
#  0.01213548 0.01171562 0.01148121 0.01059006 0.00954223 0.00944697
#  0.009107   0.00885499 0.00828868 0.00798805 0.00754094 0.00687642]
# Total explained variance: 0.9077
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
#
# Cross-Validation Results:
#    param_C param_gamma param_kernel  mean_test_score  std_test_score  \
# 0      0.1       scale       linear         0.961334        0.004635
# 1      0.1       scale          rbf         0.971429        0.006617
# 2      0.1        auto       linear         0.961334        0.004635
# 3      0.1        auto          rbf         0.970060        0.004294
# 4      0.1       0.001       linear         0.961334        0.004635
# 5      0.1       0.001          rbf         0.947648        0.006202
# 6      0.1        0.01       linear         0.961334        0.004635
# 7      0.1        0.01          rbf         0.967665        0.006524
# 8        1       scale       linear         0.961848        0.004177
# 9        1       scale          rbf         0.977588        0.004027
# 10       1        auto       linear         0.961848        0.004177
# 11       1        auto          rbf         0.980154        0.003080
# 12       1       0.001       linear         0.961848        0.004177
# 13       1       0.001          rbf         0.963730        0.005178
# 14       1        0.01       linear         0.961848        0.004177
# 15       1        0.01          rbf         0.975021        0.005284
# 16      10       scale       linear         0.961677        0.003954
# 17      10       scale          rbf         0.978956        0.001920
# 18      10        auto       linear         0.961677        0.003954
# 19      10        auto          rbf         0.979299        0.001745
# 20      10       0.001       linear         0.961677        0.003954
# 21      10       0.001          rbf         0.969376        0.004603
# 22      10        0.01       linear         0.961677        0.003954
# 23      10        0.01          rbf         0.978272        0.003924
#
#     rank_test_score
# 0                20
# 1                 7
# 2                20
# 3                 8
# 4                20
# 5                24
# 6                20
# 7                10
# 8                12
# 9                 5
# 10               12
# 11                1
# 12               12
# 13               11
# 14               12
# 15                6
# 16               16
# 17                3
# 18               16
# 19                2
# 20               16
# 21                9
# 22               16
# 23                4
#
# Best SVM Model Performance after PCA and Grid Search:
#   Best Parameters: {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
#   Accuracy: 0.9808
#   Precision: 0.9754
#   Recall: 0.9674
#   F1-Score: 0.9714
#   AUC-ROC: 0.9960
#   Grid Search Time (s): 24.8381
#
# Note: MAP-50 is not directly applicable for binary classification.
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   4.6s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   2.1s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   2.1s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   1.7s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   2.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   1.4s
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time=   7.4s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   4.1s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   2.0s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   2.2s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.9s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   1.9s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   1.7s
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time=   7.7s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   4.7s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   2.1s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.5s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=  10.7s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   1.1s
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time=   1.1s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=   1.1s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.3s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   2.4s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   1.6s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   2.1s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   1.4s
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time=   7.4s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   3.7s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   2.3s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   2.1s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.9s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   2.1s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   1.6s
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time=   8.3s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   4.7s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   2.0s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   2.3s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   9.5s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   1.4s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   4.5s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   1.8s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   2.4s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   1.6s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   2.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   1.4s
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time=   7.1s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   4.3s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   2.1s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   2.5s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   1.9s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=  10.0s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   3.4s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.1s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   2.6s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   9.9s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   1.2s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   1.1s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   6.4s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.7s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   8.9s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   3.7s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.8s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   2.4s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   9.4s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   1.2s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   3.5s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   2.4s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   2.1s
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time=   2.3s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=  10.2s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   1.1s
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time=   1.0s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=   1.1s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.4s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   2.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   1.7s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   1.9s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   1.4s
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time=   6.9s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   4.3s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   2.1s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   2.5s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   1.8s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   8.5s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   1.2s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   3.3s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.3s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   2.2s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   1.6s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=  10.2s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   3.6s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   2.1s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   2.1s
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time=   2.0s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   1.5s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=   8.5s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   1.5s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   7.1s
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time=   2.4s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=  10.2s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   1.2s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   6.3s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   1.6s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=   9.0s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   3.8s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   2.3s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   2.3s
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time=   2.2s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   2.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   1.4s
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time=   6.9s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   4.2s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   2.0s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   2.3s
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time=   2.4s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   9.5s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   3.3s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.2s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   2.9s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   1.5s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=   9.9s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   3.4s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.6s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   1.9s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   8.5s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   1.2s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   1.3s
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time=   1.2s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=   1.3s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   2.0s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   2.1s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   3.0s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   1.7s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   1.6s
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time=   7.5s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   4.5s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   1.8s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   2.6s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   1.5s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=  10.3s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   4.6s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   1.9s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   2.5s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   8.8s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   1.3s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   1.2s
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time=   1.2s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=   1.2s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.7s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   2.2s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=  10.2s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   1.3s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   6.6s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=  10.4s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   1.1s
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time=   1.1s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=   1.1s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.2s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   2.3s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   1.6s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   8.6s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   1.4s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   6.9s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   3.3s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   1.9s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   1.7s
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time=   7.9s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   4.6s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   1.8s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   2.6s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=  10.6s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   1.3s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   4.7s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   2.3s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.8s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   8.4s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   1.1s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   1.3s
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time=   1.2s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=   1.2s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.7s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   2.5s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=  10.6s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   3.9s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   2.5s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   2.6s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=  10.7s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   1.2s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   1.1s
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time=   1.0s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=   1.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.4s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   2.5s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   8.8s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   1.2s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   1.4s
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time=   1.3s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=   1.3s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   2.3s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   2.4s
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time=   2.2s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   1.6s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=   9.0s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   1.2s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   5.5s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   2.1s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   1.6s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   9.5s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   1.1s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   1.2s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   5.8s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   1.5s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=   8.3s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   4.1s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   1.9s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   2.4s
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time=   2.0s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   1.9s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=   9.0s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   1.2s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   5.7s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.4s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   1.5s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=  10.2s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   3.7s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   2.0s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   2.4s
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time=   1.9s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   8.3s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   1.2s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   4.1s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   2.5s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   2.4s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   1.8s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   1.6s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=   9.0s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   1.2s
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time=   1.1s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=   1.2s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   2.1s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   2.3s
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time=   2.3s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   1.5s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=   9.5s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   1.2s
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time=   1.2s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=   1.2s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   2.3s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   2.0s
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time=   2.3s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   9.7s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   1.5s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   7.0s
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time=   2.2s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   1.8s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=   9.3s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   1.3s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   5.8s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.5s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   1.5s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=  10.1s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   3.6s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   2.1s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   2.1s
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time=   2.0s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   1.5s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=   9.1s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   1.4s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   6.4s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   3.0s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   9.6s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   1.1s
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time=   1.2s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=   1.2s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.2s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   2.3s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   1.7s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   2.4s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   1.3s
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time=   7.8s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   1.1s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   5.8s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   2.0s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   9.7s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   1.3s
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time=   1.2s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=   1.2s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.5s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   2.3s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   9.6s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   1.3s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   1.2s
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time=   1.1s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=   1.1s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.3s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   2.2s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   1.5s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   2.2s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   1.4s
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time=   8.2s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   1.1s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   6.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.7s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   1.5s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=   8.2s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   3.6s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.5s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   2.0s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   8.6s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   1.2s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   1.3s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   1.2s
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time=   1.2s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=   1.1s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   2.4s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   2.6s
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time=   2.1s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   2.3s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   1.5s
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time=   8.2s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   4.6s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   2.2s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   2.4s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   9.7s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   4.0s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   2.2s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   2.4s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   1.7s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   1.6s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=   8.6s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   1.1s
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time=   1.2s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=   1.2s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   2.4s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   2.5s
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time=   2.3s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   2.3s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   1.4s
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time=   8.5s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   1.1s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   6.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.7s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   1.5s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=   8.4s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   1.6s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   7.3s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   2.1s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   2.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   1.6s
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time=   7.9s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   4.3s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   1.7s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   2.4s
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time=   2.3s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   2.3s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   1.5s
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time=   8.4s
